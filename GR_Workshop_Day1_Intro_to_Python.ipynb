# %% [markdown]
# <a href="https://colab.research.google.com/github/jerjesporlles/GRC/blob/main/GR_Workshop_Day1_Intro_to_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Hello 👋
#
# **Welcome to your google colab introduction to python  🐍 and geospatial modeling 🌍 script**
#
# Creator:
# Connor Smith
# connor@zanskar.us

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1X8j6IYUfyn5uJlG5ytSX5bdz_5aU3h-w?usp=sharing)
#
#   <td>
#     <a target="_blank" href="https://github.com/Zanskar-Geothermal/GRC_2022_Workshop_Zanskar"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>

# %% [markdown]
# Below we will be learning about
#
# *  Python Data Structures
# *  Numpy
# *  Matplotlib
# *  Pandas/data import
# *  Scikit Learn

# %% [markdown]
# Colab is a cloud based environment for running python codes. Check out the tabs above and those on the left. Notice that the file extension above is a 'ipynb', this is a notebook format that is especially useful for annotating code and making a report style script.

# %% [markdown]
# One of the first things to notice is that you can select the option to create a section of text or code and exucute it by using shift + enter
#
# Other than shift+enter, code can be run by pressing the play button on the left or going to 'Runtime' tab above and selecting run selection or run all

# %% [markdown]
# hi

# %% [markdown]
# Lots more to discover on you own, but for now to get into data structures ✨
#
#  This section will cover:
# *   string
# *   float
# *   int
# *   boolean
# *   list
# *   dictionary
# *   tuple
# *   loop
# *   function

# %%
#Good coding requires lots of comments! 

#You can comment in your code using the # or else using three quotation marks: 

"""We will review the four basic data types: a string, an int (integer), a float, and a boolean"""
# Out:
# 'We will review the four basic data types: a string, an int (integer), a float, and a boolean'

# %%
#Note that in python you must properly indent your code. The first line can't have an indent.

#Creation of string

print('First up, is a string, strings can be any combo of letters/numbers/symbols but they are designated by quotation marks')
# Out:
# First up, is a string, strings can be any combo of letters/numbers/symbols but they are designated by quotation marks

# %%
#Define variable string_example

string_example = '2'

#2 may be a number, but in quotations we are labeling it as string!
print(string_example, type(string_example))
# Out:
# 2 <class 'str'>

# %%
#Next is an int, these are whole numerical values

#Define variable x 
x=2 
print(x, type(x))
# Out:
# 2 <class 'int'>

# %%
#Next is a float, a numerical value with decimals
x = 2.02
print(x,  type(x))
# Out:
# 2.02 <class 'float'>

# %%
#Finally, a Boolean. Boolean values are either True or False. Booleans are used for ascribing logic to your code 👩‍💻 🧑‍💻 
x= True
print(x,type(x))
# Out:
# True <class 'bool'>

# %%
#A statement like 1>2 is a false boolean.     
print(1>2)
# Out:
# False

# %%
#Whereas a = a is a true boolean
print('a'=='a') #Another thing to note is that two equal signs are needed here
# Out:
# True

# %% [markdown]
# Next we will be learning about different ways to group data together. We can define data types by using things like quotation marks for a string, and how we enclose them: for example (), [], {}

# %%
#List. Lists are defined by brackets []   
List = ['Geo']  
print(List)
# Out:
# ['Geo']

# %%
# Creating a Multi-Dimensional (2D) List  
List = [['Geo', 'Coders'], ['Rock']]  
print(List)
# Out:
# [['Geo', 'Coders'], ['Rock']]

# %%
#Accessing elements from the List 

List = [1, 2, 3, 4, 5, 6]  
#Use the index operator [ ] to access an item in a list. 
#In Python, negative sequence indexes represent positions from the end of the array. 
     
# accessing a element
#Note again that in python 0 is the first element!
print(List[0])   
print(List[2]) 

# We can also use negative indexing
# Here we print the last element of list  
print(List[-1])
# Out:
# 1
# 3
# 6

# %%
#Next we will look at a Dictionary. Dictionaries let us store/nest values with indexable keys. We use { } for dictionaries 
Dict = {1: 'The', 2: 'Geo', 3: 'Duck', 4: 'is a', 5: 'strange', 
        6: 'burrowing', 7: 'clam', 8: 'not a', 9: 'quacking',
        10: 'Earth', 11:'scientist'}
print(Dict)
# Out:
# {1: 'The', 2: 'Geo', 3: 'Duck', 4: 'is a', 5: 'strange', 6: 'burrowing', 7: 'clam', 8: 'not a', 9: 'quacking', 10: 'Earth', 11: 'scientist'}

# %% [markdown]
# fun fact geoducks can live 140 years! https://en.wikipedia.org/wiki/Geoduck.  and the name comes from the Salish tribe

# %%
#We can call one key
Dict[1]
# Out:
# 'The'

# %%
#Or we can call several! In any order we like. Here is a haiku  
Silly_scentence =  Dict[5],Dict[2],Dict[11]
Silly_scentence2 = Dict[8],Dict[6],Dict[10],Dict[3]
Silly_scentence3 = Dict[8],Dict[9],Dict[7]

print(Silly_scentence)  
print(Silly_scentence2)  
print(Silly_scentence3)
# Out:
# ('strange', 'Geo', 'scientist')
# ('not a', 'burrowing', 'Earth', 'Duck')
# ('not a', 'quacking', 'clam')

# %%
#Note that with most data structures the elements cant be changed, meaning they are mutable.

#The last basic data structure that we can use is a tuple. Tuples are written in parentheses. 

x = (1,2,3,4)

x[3]
# Out:
# 4

# %%
##Note that with most data structures the elements cant be changed, meaning they are mutable. 
##A tuple is a list but it is immutable! Meaning the elements cant be changed.

##Try unhashing the code below are running, note your code will have an error! We cant change a tuple element

#x[3] = 5


##There are some cases where you don't want to lose your elements when you are naming 
##multiple varaibles so tuples can be more favorable that lists..

# %%
#Next we will see an example of a for loop that appends values to a list. Append works with lists, arrays, and dictionaries

#Start with an empty list
List = [] 

#make a variable K that has a range of 5
K = range(5)
for i in K:
  x = 1 + i #  Add one for each value in the range of 5 (0-4 in python), repeat until we iterate through all 5 values! 
  List.append(x)
List
# Out:
# [1, 2, 3, 4, 5]

# %%
#Functions are very useful to automate and modulate code. Python gives us many function (e.g., print), we can also create our own
"""This is a simple function with a singular input, an if statement, and two possible outputs. 
To set up  a function preface with def, then set keyword (here it is say_hi) and input parameters (input)
Follow that with a colon :"""

def say_hi(input):
  if input == str('hi'): 
    print('Whats up Geo-Ducks, whats quacking?')
  else:
    print(Silly_scentence) #This was something we used in the dictionary!

#call the function
say_hi('hi')
# Out:
# Whats up Geo-Ducks, whats quacking?

# %%
##If we dont say hi what happens? 

##Try for yourself! Uncomment the code below and write something in between the parenthesis

say_hi(' sup ') ##UNHASH ME 🦆
# Out:
# ('strange', 'Geo', 'scientist')

# %%
# %%html
# <iframe src="https://drive.google.com/file/d/1BxU_dfnZyS0GhTVekx7yqp1f358DuOs-/preview" width="640" height="480" allow="autoplay"></iframe>
# Out:
# <iframe src="https://drive.google.com/file/d/1BxU_dfnZyS0GhTVekx7yqp1f358DuOs-/preview" width="640" height="480" allow="autoplay"></iframe>

# %% [markdown]
# So why is it called python?
#
# The creator Guido van Rossum was inspired by the 1970's BBC comedy series!
# https://docs.python.org/3/faq/general.html#:~:text=Details%20here.-,Why%20is%20it%20called%20Python%3F,to%20call%20the%20language%20Python

# %% [markdown]
# #✨ Modules ✨

# %% [markdown]
# Below we will look at four commonly used python modules, including:
#
# *   Numpy
# *   Matplotlib
# *   Pandas
# *   Scikit learn
#
# These are just readily available code blocks/functions that can be imported inside another Python Program.
#
# (Note that we can create our own modules as .py files, something to try later on!)

# %% [markdown]
# Numpy is helpful for math with arrays, lists, matricies, etc., of data and to access built in functions (e.g., sin, pi, sqrt). For more check out https://numpy.org/

# %%
#We can do most basic addition, subtraction, multiplication, etc., operations without defining any function

x = 2+2
x
# Out:
# 4

# %%
#Here we access the numpy module. we can create our own modules and access those as well!
#with import we make code in one module available in another.

#we can turn the import into an acronym for simplicity (np)

import numpy as np

# %% [markdown]
# Guess what numpy offers... a whole new data structure: Arrays ✨ 🐬
#
# Arrays are similar to lists but all elements are the same type (can be strings, ints, floats, booleans).

# %%
#Why are array's useful? because we can do operations between different data types 

List_1 = [1, 2, 3]

List_2 = [1.1,2.2,3.3]

#Why are array's useful? because we can do operations between different numerical data types 

#See below if you unhash z and try to multiply these lists we get an error


#z = List_1*List_2 ##UNHASH ME 😈
#print(z)

# %%
#Example array. We take the lists above (in brackets) and convert them to arrays 


x = np.array(List_1)
y = np.array(List_2)

#Now what happens when we multiply these arrays? 

z = x*y
print(z, 'success! ⭐️ ')
# Out:
# [1.1 4.4 9.9] success! ⭐️

# %%
#With numpy we can also call functions like square root 

z = np.sqrt(x*y)
print(z, 'success! ⭐️ ')
# Out:
# [1.04880885 2.0976177  3.14642654] success! ⭐️

# %% [markdown]
# Matplotlib
#
# Matplot lib is used to visualize data and builds on the numpy framework. For more check out https://matplotlib.org/

# %%
#we can turn the import into an acronym for simplicity (plt)

import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)

plt.plot(x,y) #note that plots can overlay eachother

plt.title('X vs Y',fontsize = 25)
plt.xlabel('x',fontsize = 18)
plt.ylabel('y',fontsize = 18)
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# Pandas
#
# Pandas is a very effective module to handle and import data. For more check out https://pandas.pydata.org/

# %%
#we can turn the import into an acronym for simplicity (pd)

import pandas as pd

# %%
x
# Out:
# array([1, 2, 3])

# %%
y
# Out:
# array([1.1, 2.2, 3.3])

# %%
Dataframe = pd.DataFrame([x,y], columns = ['Val1','Val2','Val3'])

Dataframe.head()
# Out:
#    Val1  Val2  Val3
# 0   1.0   2.0   3.0
# 1   1.1   2.2   3.3

# %%
#@title
text = 'How are we feeling?' #@param {type: "string"}
dropdown = '\uD83D\uDE03 ' #@param ["😃 ","👍 ","😟 ", "😢 "]{allow-input:true}

#print(text = 'value')
#print(dropdown)

# %% [markdown]
# #Spatial modeling
#
# -Looking at correlation stats
#
# -Plotting fun with leafmap
#
# -PCA/Clustering
#
# Original data: http://www.nbmg.unr.edu/geothermal/Data.html
#
# Link to prepared dataset: https://raw.githubusercontent.com/Zanskar-Geothermal/GRC_2022_Workshop_Zanskar/main/NV_PFA_TSITES_WORKSHOP.csv
#
# Link to study resources: https://gbcge.org/current-projects/machine-learning/
#
#
#  https://github.com/NBMG-UNR

# %%
#We can use pandas to work with different files. 
#It can both read and write files, such as csv, excel, txt, html, pickle, etc., 

#For this example and the next module we have data stored as a csv accessible through a GITHUB link 
url ='https://raw.githubusercontent.com/Zanskar-Geothermal/GRC_2022_Workshop_Zanskar/main/NV_PFA_TSITES_WORKSHOP.csv'

# %% [markdown]
# About the dataset:
#
# *   145 Training sites (83 positive and 62 negative)
# *   Positive sites are known geothermal systems (>37C)
# *   Negative sites are deep (>1km) and cool (bottom hole temperatures are equal to or below predicted geothermal gradient values)
# *   Temperatures for positive sites are max temp (C) of geothermometry or well measurement. Temperatures for negative sites are the delta between gradients at the depth of the well
# *   Input data represent unbiased features
# *   Data is already standardized! (mean = 0 and variance = 1)

# %%
#pandas can read the url as a csv and output a dataframe (table)

df = pd.read_csv(url)
df.head()
# Out:
#    Id  QuaternaryFaultDensity  HorizGravityGradient  GeodeticStrainRate  \
# 0   1               -0.027410              0.039597           -0.986603
# 1   2                0.448726              1.691345            1.009808
# 2   3                1.070970              0.373260           -0.178363
# 3   4                0.200934              4.269271            0.042698
# 4   5               -1.298479              0.529496           -0.529951
#
#    QuaternarySlipRate  FaultRecency  FaultSlipDilationTendency  Earthquakes  \
# 0           -1.008622     -0.733905                   1.014094    -0.206034
# 1           -0.063892     -0.495543                   0.220369    -0.071266
# 2            0.011734     -0.882393                   1.102452    -1.200670
# 3            0.925116     -0.450002                  -0.652574     0.779572
# 4           -1.124389     -0.157383                  -1.131318    -0.041029
#
#    HorizMagneticGradient  Heatflow    DEM30m   Longitude   Latitude  \
# ...

# %%
#See the type of data structure for each column
df.dtypes
# Out:
# Id                             int64
# QuaternaryFaultDensity       float64
# HorizGravityGradient         float64
# GeodeticStrainRate           float64
# QuaternarySlipRate           float64
# FaultRecency                 float64
# FaultSlipDilationTendency    float64
# Earthquakes                  float64
# HorizMagneticGradient        float64
# Heatflow                     float64
# DEM30m                       float64
# Longitude                    float64
# Latitude                     float64
# NAME                          object
# MAX_Temp_C                   float64
# Blind_Status                  object
# NET_POWER_Mwe_2018           float64
# Depth_m                      float64
# TrainCode                      int64
# dtype: object

# %%
#See some of the basic stats for each column 
df.describe()
# Out:
#                Id  QuaternaryFaultDensity  HorizGravityGradient  \
# count  145.000000              145.000000            145.000000
# mean    73.000000               -0.009606              0.690641
# std     42.001984                1.002074              1.377316
# min      1.000000               -1.524225             -1.336602
# 25%     37.000000               -0.724513             -0.328935
# 50%     73.000000               -0.190937              0.447108
# 75%    109.000000                0.608711              1.543072
# max    145.000000                2.961233              6.310420
#
#        GeodeticStrainRate  QuaternarySlipRate  FaultRecency  \
# count          145.000000          145.000000    145.000000
# mean            -0.154082            0.038562      0.266239
# std              1.059143            1.068881      1.108427
# min             -2.460788           -1.743722     -2.029360
# 25%             -1.018777           -0.816779     -0.678824
# ...

# %%
# %%html
# <iframe src="https://drive.google.com/file/d/1u7ReEsbrucQO4jxNTUibkqzSPlQ-tzo8/preview" width="640" height="480" allow="autoplay"></iframe>
# Out:
# <iframe src="https://drive.google.com/file/d/1u7ReEsbrucQO4jxNTUibkqzSPlQ-tzo8/preview" width="640" height="480" allow="autoplay"></iframe>

# %%
#Create a dataframe with features
X = df[['QuaternaryFaultDensity', 'HorizGravityGradient',
       'GeodeticStrainRate', 'QuaternarySlipRate', 'FaultRecency',
       'FaultSlipDilationTendency', 'Earthquakes', 'HorizMagneticGradient',
       'Heatflow','DEM30m']]


#Isolate training data labels
y = df[['TrainCode']]

#dataframe with attributes
attribute_df = df[['Id','Longitude', 'Latitude', 'NAME',
        'MAX_Temp_C','Blind_Status', 'NET_POWER_Mwe_2018', 'Depth_m']]

# %% [markdown]
# Lets look at our data in more detail

# %%
#Import widgets to interact with adjustable icons 

import ipywidgets as widgets

# %matplotlib inline
from ipywidgets import interactive

# %% [markdown]
# We can look at widget plots of our data to compare features!
#
# https://coderzcolumn.com/tutorials/data-science/interactive-charts-using-matplotlib-and-ipywidgets

# %%
@widgets.interact( feature1=X.columns, feature2=X.columns)

def create_scatter(feature1, feature2):
    with plt.style.context("ggplot"):
        fig = plt.figure(figsize=(8,4))

        pos = df[(df['TrainCode'] == 1)]
        neg = df[(df['TrainCode'] == 0)]

        label1 = 'Positive T-Site'
        label2 = 'Negative T-Site'
        
        plt.scatter(x = pos[feature1],
                    y = pos[feature2],
                    c='red',
                    s=20,edgecolor='k',label = label1)

        plt.scatter(x = neg[feature1],
                    y = neg[feature2],
                    c='yellowgreen', 
                    s=20,edgecolor='k',label = label2)

        plt.xlabel(feature1.capitalize())
        plt.ylabel(feature2.capitalize())
        plt.legend()

        plt.title("%s vs %s"%(feature1.capitalize(), feature2.capitalize()))
# Out:
# interactive(children=(Dropdown(description='feature1', options=('QuaternaryFaultDensity', 'HorizGravityGradien…

# %% [markdown]
# ###Pearson correlation plots

# %%
#Compute pairwise correlation of columns

correlation_mat = X.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(correlation_mat, dtype=bool))

import seaborn as sns
sns.set(font_scale = 1.3)
sns.set(rc={'figure.figsize':(11.7,8.27),"font.size":20,"axes.labelsize":20},style="white")

sns.set(font_scale = 1.3)
ax = sns.heatmap(correlation_mat, mask=mask, annot = True, linewidths=.95, 
                 cmap = 'viridis',annot_kws={"size": 12}, fmt='.1g',square=True, vmax=.3, center=0,)
ax.fontweight='bold'
ax.set_aspect("equal")

plt.title('Correlation Matrix ',fontsize = 22,fontweight='bold');
plt.show()
plt.tight_layout()

# %% [markdown]
# ##Plotting/playing with interactive map

# %% [markdown]
# To run commands at the VM's terminal, prefix the line with an exclamation point

# %%
# !pip install leafmap -q

# %% [markdown]
# leafmap: https://colab.research.google.com/github/giswqs/leafmap/blob/master/examples/notebooks/00_key_features.ipynb#scrollTo=VZvYgR_JwCaB

# %%
import os
import subprocess

import leafmap.foliumap as leafmap

# %%
#Geopandas is needed to access data with only leafmap
# !pip install geopandas -q
import geopandas

# %% [markdown]
# Data for geothermal fields from
# https://minerals.nv.gov/uploadedFiles/mineralsnvgov/content/home/features/RP/NDOM_Open_Data_May2020.pdf

# %%
map1 = leafmap.Map(center=(40, -117), zoom=7)


#add shapefile of study area outline 

Study_area_shp_url ='https://github.com/Zanskar-Geothermal/GRC_2022_Workshop_Zanskar/raw/main/NV_PFA_STUDY_AREA.zip'

map1.add_shp(Study_area_shp_url, layer_name="PFA Study Area",fill_colors=["none"])


#add shapefile of authorized lease locations as of 2021
Auth_Lease_url = 'https://raw.githubusercontent.com/Zanskar-Geothermal/GRC_2022_Workshop_Zanskar/main/features%20(1).geojson'
map1.add_geojson(Auth_Lease_url, layer_name="BLM Autorized GT Leases Sections")

#add training sites
map1.add_points_from_xy(df, x="Longitude", y="Latitude", popup=None)

#add heatmap of tempeartures for training sites
map1.add_heatmap(df,longitude="Longitude", latitude="Latitude", value='MAX_Temp_C', name="Heat map Temp C", radius=20)

map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ##PCA + Kmeans
#
# New module:
# Scikit learn
#
# A robust library for machine learning with many tools for ML and statistical modeling. For more info check out https://scikit-learn.org/stable/index.html

# %%
#How does PCA work? 

# %%html
<iframe src="https://drive.google.com/file/d/1ReGIafspdGDxsAqRU0eNB6kbq3FH33ac/preview" width="640" height="480" allow="autoplay"></iframe>
# Out:
# <iframe src="https://drive.google.com/file/d/1ReGIafspdGDxsAqRU0eNB6kbq3FH33ac/preview" width="640" height="480" allow="autoplay"></iframe>

# %% [markdown]
# PCA is a common technique for simplifying mutlidimensional data (e.g., 10D) into smaller dimensions (e.g., 2D) to support clustering. Kmeans clustering randomly initializes centroid locations and iteratively refines these locations until it finds an optimal centroid for each cluster group

# %%
from sklearn.decomposition import PCA
n = len(X.columns)
pcamodel = PCA(n_components=n)
pca = pcamodel.fit_transform(X)

#Index the scores from the PCA reconstruction
score = pca[:,0:2]

#Create a new dataframe with all features and PC scores

df_pcaTsite = pd.DataFrame(pca,columns=[ "PC"+str(X) for X in range(1,pcamodel.n_components_+1)])
df_pca = pd.concat([df,df_pcaTsite], axis=1, sort=False)

# %%
df_pca
# Out:
#       Id  QuaternaryFaultDensity  HorizGravityGradient  GeodeticStrainRate  \
# 0      1               -0.027410              0.039597           -0.986603
# 1      2                0.448726              1.691345            1.009808
# 2      3                1.070970              0.373260           -0.178363
# 3      4                0.200934              4.269271            0.042698
# 4      5               -1.298479              0.529496           -0.529951
# ..   ...                     ...                   ...                 ...
# 140  141               -1.524225             -0.743702           -1.113649
# 141  142               -1.398798             -0.867124           -1.398668
# 142  143               -0.190937             -0.296763           -1.175057
# 143  144               -1.365699              0.146387           -1.565202
# 144  145               -1.311365             -1.248627           -0.713859
#
# ...

# %%
#ADD ELLIPSES
from sklearn.cluster import KMeans

from scipy.spatial.distance import cdist

nCluster = 3
"""The radius of each circle is the distance between the centroid and points in
each cluster, either the min, mean, or max dist of the collection of points"""

def plot_kmeans(kmeans, X, Xneg, Xpos, n_clusters=nCluster, rseed=0, ax=None):
    labels = kmeans.fit_predict(X)


    labels_Xneg = labels[0:62]
    labels_Xpos = labels[62:145]

    # plot the input data as scatter points
    ax = ax or plt.gca()

    
    label1 = 'Negative T-Site'
    label2 = 'Positive T-Site'
    ax.scatter(Xneg[:, 0], Xneg[:, 1], c=labels_Xneg, s=85, edgecolors='k', marker='o', cmap='rainbow', label = label1, zorder=2)
    ax.scatter(Xpos[:, 0], Xpos[:, 1], c=labels_Xpos, s=285,marker=(5, 1), edgecolors='k', cmap='rainbow',label = label2, zorder=2)


    plt.grid()

    # plot ellipse representations of the KMeans clusters
    centers = kmeans.cluster_centers_ 
    radii = [cdist(X[labels == i], [center]).mean()
             for i, center in enumerate(centers)]
    for c, r in zip(centers, radii):
          ax.add_patch(plt.Circle(c, r, fc='white',ec ='cyan', lw=3, alpha = 0.5, zorder=1))

    plt.scatter(centers[:,0] , centers[:,1] , s = 380, marker='o', edgecolors='k',color = 'white')
    for i in range(centers.shape[0]):
      plt.text(centers[i,0], centers[i,1], str(i+1),fontsize=12,fontweight='bold',horizontalalignment='center', verticalalignment='center')

    ncols = 1
    plt.legend(scatterpoints=1, ncol=ncols, loc='center left',bbox_to_anchor=(1, 0.5),fontsize=20)

# %%
#ADD VECTORS

"""The loading vectors of each feature illustrate their 
  influence on the variance of our data"""

def vector_plot(score,coeff,labels=None):
    angle = 20
    var_ratio1 = float(str(round(pcamodel.explained_variance_ratio_[0]*100, 2)))
    var_ratio2 = float(str(round(pcamodel.explained_variance_ratio_[1]*100, 2)))
    xs = score[:,0]
    ys = score[:,1]
    n = coeff.shape[0]
    for i in range(n):
        plt.arrow(0, 0, coeff[i,0]*10, coeff[i,1]*10,color = 'k',alpha = 0.5, lw = 2 ) #Multiply BY 10 to fit axes
        if labels is None:
            plt.text(coeff[i,0]* 1.05, coeff[i,1] * 1.05, "Var"+str(i+1), color = 'k', ha = 'center', va = 'center')

        else:
            plt.text(coeff[i,0]* 10.00, coeff[i,1] * 10.00, labels[i],color = 'k',horizontalalignment='center', verticalalignment='center_baseline', rotation=angle, rotation_mode='anchor', fontsize=12,fontweight='bold')
 
    plt.xlabel('PC1 ' + str(var_ratio1) + '%',fontsize=20)
    plt.ylabel('PC2 ' + str(var_ratio2) + '%',fontsize=20)

# %% [markdown]
# [This Colab demo](https://colab.research.google.com/notebooks/widgets.ipynb#scrollTo=_00aYIMEXVGS) will explain how the plotting widgets (tabs) work.

# %%
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable
import mpl_toolkits.axisartist.floating_axes as floating_axes

# %%
import sys
IN_COLAB = 'google.colab' in sys.modules
IN_COLAB
# Out:
# True

# %%
if IN_COLAB:
    from google.colab import widgets

# %%
#Organize principal components by train code 
df_pca = df_pca.sort_values(by='TrainCode',ascending = True)

df_pca_neg = df_pca[df_pca['TrainCode']==0] 
df_pca_pos = df_pca[df_pca['TrainCode']==1] 

df_pca_pos = df_pca_pos[['PC1','PC2']]
df_pca_pos = df_pca_pos.to_numpy()
df_pca_neg = df_pca_neg[['PC1','PC2']]
df_pca_neg = df_pca_neg.to_numpy()

#Isolate only the first PC values for plot_kmeans function 
df_pca_first_two = df_pca[['PC1','PC2']]
df_pca_first_two = df_pca_first_two.to_numpy()

# %%
n_clusters =  [2,3,4,5]

if IN_COLAB:
    tb3 =  widgets.TabBar([str(n_clusters[i]) +' Clusters ' for i in range(np.shape(n_clusters)[0])])
else:
  fig, myax = plt.subplots(figsize=[10,15],ncols = 2, nrows = np.shape(n_clusters)[0])

for i in range(np.shape(n_clusters)[0]):  
  
  with tb3.output_to(i, select=(i < 2)):

    #Call the kmeans plotting function 
    kmeans = KMeans(n_clusters=i+2, random_state=42)
    plot_kmeans(kmeans,df_pca_first_two,df_pca_neg,df_pca_pos) 

    #Call the loading vector plotting function 
    vector_plot(pca[:,0:2],np.transpose(pcamodel.components_[0:2, :]),list(X.columns))
    plt.xlim([-4, 6])
    plt.ylim([-6, 10]) 
    plt.tight_layout()
# Out:
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id1"></div>

# %% [markdown]
# Vector length represents the weighting of that variable, or its influence on the corresponding PCs.

# %% [markdown]
# We can visually assume that ~3 clusters works best for the data. We can also look at a metric like within-group sum of squares
#
# which is this calculation
#  <font size="5">
#  $\ ss = \Sigma_{j=1}^{K} \Sigma_{i=1}^{l} (\bar{X}(j) - \bar{X}(i))^2$
#     </font>
#
# Representing the differences among group means (i.e. distortion)

# %%
fig= plt.figure(figsize=(7,5)) 

#Append distortions to list
distortions = []
for i in range(1, 9): #test cluster values from 1-9
    km = KMeans(n_clusters=i, init='k-means++') 
    #Fit K-means to the first PCs which explain the most variance
    km.fit(df_pca_first_two)
    distortions.append(km.inertia_)
K = range(1, 9)

plt.plot(K,distortions,marker='o')
plt.grid()
plt.xlabel('Number of clusters')
plt.ylabel('Within-Group Sum of Squares')
plt.title('Clusters (K) vs Distortion',fontweight='bold')
plt.tight_layout ()

# %%
fig= plt.figure(figsize=(11,8)) 

#plot kmeans data
kmeans = KMeans(n_clusters=3, random_state=42)
plot_kmeans(kmeans,df_pca_first_two,df_pca_neg,df_pca_pos) 
vector_plot(pca[:,0:2],np.transpose(pcamodel.components_[0:2, :]),list(X.columns))
plt.xlim([-4, 6])
plt.ylim([-6, 10])
# Out:
# (-6.0, 10.0)

# %%
#Append kmeans info to a new dataframe 
Labels = kmeans.labels_

centers = np.copy(kmeans.cluster_centers_)
df_labels = pd.DataFrame({'KMeansGrp':Labels,
                          'Grp0_CntrX':centers[0,0],
                          'Grp0_CntrY':centers[0,1],
                          'Grp1_CntrX':centers[1,0],
                          'Grp1_CntrY':centers[1,1]},dtype=int)

df_clustered = pd.concat([df_pca, df_labels], axis=1, sort=False)

df_clustered.head()
# Out:
#    Id  QuaternaryFaultDensity  HorizGravityGradient  GeodeticStrainRate  \
# 0   1               -0.027410              0.039597           -0.986603
# 1   2                0.448726              1.691345            1.009808
# 2   3                1.070970              0.373260           -0.178363
# 3   4                0.200934              4.269271            0.042698
# 4   5               -1.298479              0.529496           -0.529951
#
#    QuaternarySlipRate  FaultRecency  FaultSlipDilationTendency  Earthquakes  \
# 0           -1.008622     -0.733905                   1.014094    -0.206034
# 1           -0.063892     -0.495543                   0.220369    -0.071266
# 2            0.011734     -0.882393                   1.102452    -1.200670
# 3            0.925116     -0.450002                  -0.652574     0.779572
# 4           -1.124389     -0.157383                  -1.131318    -0.041029
#
#    HorizMagneticGradient  Heatflow  ...       PC6       PC7       PC8  \
# ...

# %% [markdown]
# ###Spatial plot of cluster results!

# %% [markdown]
# Lets see how our results look spatially

# %%
import folium

# %%
map3 = folium.Map(center=(40, -117), min_zoom=7)

folium.Map()
def color(cluster):
    if cluster ==0:
        col = 'blue'
    elif cluster ==1:
        col = 'purple'
    else:
        col='green'
    return col


for lat,lan,name,cluster in zip(df_clustered['Latitude'],df_clustered['Longitude'],df_clustered['NAME'],df_clustered['KMeansGrp']):
  
 folium.Marker(location=[lat,lan],popup = name,
                 icon= folium.Icon(color=color(cluster),
                 icon_color='yellow',icon = 'cloud')).add_to(map3)




Study_area_shp_url =  geopandas.read_file('https://github.com/Zanskar-Geothermal/GRC_2022_Workshop_Zanskar/raw/main/NV_PFA_STUDY_AREA.zip')


folium.GeoJson(data=Study_area_shp_url["geometry"]).add_to(map3)

map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ##Take home - Play with your own data!
#
# to unhase values below use 'shft + command  + /'

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
#leafmap vs leafmap.foliumap allows the user to use a graphic user interface with advanced capabilities (tools,web data, etc.,)

import leafmap

# %%
##click on the wrench in the top right and start playing with your own data!

map2 = leafmap.Map(center=(40, -117), zoom=7)

map2
# Out:
# Map(center=[40, -117], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %% [markdown]
# Try supervised learning with scikit learn and the training site data!
#
# https://scikit-learn.org/stable/supervised_learning.html#supervised-learning
